# %%
# !pip install pmdarima
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pmdarima in c:\users\logith.r\appdata\roaming\python\python310\site-packages (2.0.4)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\logith.r\appdata\roaming\python\python310\site-packages (from pmdarima) (3.0.11)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\anaconda3\lib\site-packages (from pmdarima) (0.13.5)
# Requirement already satisfied: numpy>=1.21.2 in c:\anaconda3\lib\site-packages (from pmdarima) (1.23.5)
# Requirement already satisfied: pandas>=0.19 in c:\anaconda3\lib\site-packages (from pmdarima) (1.5.3)
# Requirement already satisfied: urllib3 in c:\anaconda3\lib\site-packages (from pmdarima) (1.26.14)
# Requirement already satisfied: scikit-learn>=0.22 in c:\anaconda3\lib\site-packages (from pmdarima) (1.2.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\anaconda3\lib\site-packages (from pmdarima) (1.10.0)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\anaconda3\lib\site-packages (from pmdarima) (65.6.3)
# Requirement already satisfied: packaging>=17.1 in c:\anaconda3\lib\site-packages (from pmdarima) (22.0)
# Requirement already satisfied: joblib>=0.11 in c:\anaconda3\lib\site-packages (from pmdarima) (1.1.1)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\anaconda3\lib\site-packages (from scikit-learn>=0.22->pmdarima) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\anaconda3\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: six in c:\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)

# %%
# !pip install prophet
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: prophet in c:\users\logith.r\appdata\roaming\python\python310\site-packages (1.1.5)
# Requirement already satisfied: tqdm>=4.36.1 in c:\anaconda3\lib\site-packages (from prophet) (4.64.1)
# Requirement already satisfied: cmdstanpy>=1.0.4 in c:\users\logith.r\appdata\roaming\python\python310\site-packages (from prophet) (1.2.4)
# Requirement already satisfied: pandas>=1.0.4 in c:\anaconda3\lib\site-packages (from prophet) (1.5.3)
# Requirement already satisfied: numpy>=1.15.4 in c:\anaconda3\lib\site-packages (from prophet) (1.23.5)
# Requirement already satisfied: importlib-resources in c:\users\logith.r\appdata\roaming\python\python310\site-packages (from prophet) (6.4.5)
# Requirement already satisfied: holidays>=0.25 in c:\users\logith.r\appdata\roaming\python\python310\site-packages (from prophet) (0.57)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\anaconda3\lib\site-packages (from prophet) (3.7.0)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in c:\users\logith.r\appdata\roaming\python\python310\site-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: python-dateutil in c:\anaconda3\lib\site-packages (from holidays>=0.25->prophet) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (22.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (9.4.0)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda3\lib\site-packages (from pandas>=1.0.4->prophet) (2022.7)
# Requirement already satisfied: colorama in c:\anaconda3\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\anaconda3\lib\site-packages (from python-dateutil->holidays>=0.25->prophet) (1.16.0)

# %%
# !pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: plotly in c:\users\logith.r\appdata\roaming\python\python310\site-packages (5.24.1)
# Requirement already satisfied: packaging in c:\anaconda3\lib\site-packages (from plotly) (22.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\anaconda3\lib\site-packages (from plotly) (8.0.1)

# %%
# !pip install statsmodels
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: statsmodels in c:\anaconda3\lib\site-packages (0.13.5)
# Requirement already satisfied: patsy>=0.5.2 in c:\anaconda3\lib\site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: scipy>=1.3 in c:\anaconda3\lib\site-packages (from statsmodels) (1.10.0)
# Requirement already satisfied: numpy>=1.22.3 in c:\anaconda3\lib\site-packages (from statsmodels) (1.23.5)
# Requirement already satisfied: pandas>=0.25 in c:\anaconda3\lib\site-packages (from statsmodels) (1.5.3)
# Requirement already satisfied: packaging>=21.3 in c:\anaconda3\lib\site-packages (from statsmodels) (22.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\anaconda3\lib\site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda3\lib\site-packages (from pandas>=0.25->statsmodels) (2022.7)
# Requirement already satisfied: six in c:\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from plotly import express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
# %matplotlib inline

# %%
from pmdarima import auto_arima
from sklearn.metrics import mean_absolute_percentage_error
from scipy.stats import mode, norm, skew

import statsmodels.api as sm
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error 

from prophet import Prophet
from prophet.plot import plot_plotly
from prophet.diagnostics import performance_metrics
from prophet.diagnostics import cross_validation

# %%
import warnings
import time
import datetime
import pickle

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('Hotel_Bookings.csv')
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
# 2                        0                     1       1  ...    No Deposit
# 3                        0                     1       1  ...    No Deposit
# 4                        0                     2       2  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type   adr  \
# 0    NaN     NaN                    0     Transient   0.0
# 1    NaN     NaN                    0     Transient   0.0
# 2    NaN     NaN                    0     Transient  75.0
# 3  304.0     NaN                    0     Transient  75.0
# 4  240.0     NaN                    0     Transient  98.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 0                            0                          0           Check-Out
# 1                            0                          0           Check-Out
# 2                            0                          0           Check-Out
# 3                            0                          0           Check-Out
# 4                            0                          1           Check-Out
#
#   reservation_status_date
# 0              2015-07-01
# 1              2015-07-01
# 2              2015-07-02
# 3              2015-07-02
# 4              2015-07-03
#
# [5 rows x 32 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
#  12  meal                            119390 non-null  object
#  13  country                         118902 non-null  object
#  14  market_segment                  119390 non-null  object
#  15  distribution_channel            119390 non-null  object
#  16  is_repeated_guest               119390 non-null  int64
#  17  previous_cancellations          119390 non-null  int64
#  18  previous_bookings_not_canceled  119390 non-null  int64
#  19  reserved_room_type              119390 non-null  object
#  20  assigned_room_type              119390 non-null  object
#  21  booking_changes                 119390 non-null  int64
#  22  deposit_type                    119390 non-null  object
#  23  agent                           103050 non-null  float64
#  24  company                         6797 non-null    float64
#  25  days_in_waiting_list            119390 non-null  int64
#  26  customer_type                   119390 non-null  object
#  27  adr                             119390 non-null  float64
#  28  required_car_parking_spaces     119390 non-null  int64
#  29  total_of_special_requests       119390 non-null  int64
#  30  reservation_status              119390 non-null  object
#  31  reservation_status_date         119390 non-null  object
# dtypes: float64(4), int64(16), object(12)
# memory usage: 29.1+ MB

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# max                   53.000000                  31.000000
#
#        stays_in_weekend_nights  stays_in_week_nights         adults  \
# count            119390.000000         119390.000000  119390.000000
# mean                  0.927599              2.500302       1.856403
# std                   0.998613              1.908286       0.579261
# min                   0.000000              0.000000       0.000000
# 25%                   0.000000              1.000000       2.000000
# 50%                   1.000000              2.000000       2.000000
# 75%                   2.000000              3.000000       2.000000
# max                  19.000000             50.000000      55.000000
#
#             children         babies  is_repeated_guest  \
# count  119386.000000  119390.000000      119390.000000
# mean        0.103890       0.007949           0.031912
# std         0.398561       0.097436           0.175767
# min         0.000000       0.000000           0.000000
# 25%         0.000000       0.000000           0.000000
# 50%         0.000000       0.000000           0.000000
# 75%         0.000000       0.000000           0.000000
# max        10.000000      10.000000           1.000000
#
#        previous_cancellations  previous_bookings_not_canceled  \
# count           119390.000000                   119390.000000
# mean                 0.087118                        0.137097
# std                  0.844336                        1.497437
# min                  0.000000                        0.000000
# 25%                  0.000000                        0.000000
# 50%                  0.000000                        0.000000
# 75%                  0.000000                        0.000000
# max                 26.000000                       72.000000
#
#        booking_changes          agent      company  days_in_waiting_list  \
# count    119390.000000  103050.000000  6797.000000         119390.000000
# mean          0.221124      86.693382   189.266735              2.321149
# std           0.652306     110.774548   131.655015             17.594721
# min           0.000000       1.000000     6.000000              0.000000
# 25%           0.000000       9.000000    62.000000              0.000000
# 50%           0.000000      14.000000   179.000000              0.000000
# 75%           0.000000     229.000000   270.000000              0.000000
# max          21.000000     535.000000   543.000000            391.000000
#
#                  adr  required_car_parking_spaces  total_of_special_requests
# count  119390.000000                119390.000000              119390.000000
# mean      101.831122                     0.062518                   0.571363
# std        50.535790                     0.245291                   0.792798
# min        -6.380000                     0.000000                   0.000000
# 25%        69.290000                     0.000000                   0.000000
# 50%        94.575000                     0.000000                   0.000000
# 75%       126.000000                     0.000000                   1.000000
# max      5400.000000                     8.000000                   5.000000

# %%
features_stat = df.isna().sum().rename('num_of_missing').reset_index()
features_stat.columns = ['feature', 'num_of_missing']
features_stat['percentage_of_missings'] = features_stat['num_of_missing'].apply(lambda x:x/len(df))
features_stat.sort_values(by='percentage_of_missings',ascending=False)
# Out:
#                            feature  num_of_missing  percentage_of_missings
# 24                         company          112593                0.943069
# 23                           agent           16340                0.136862
# 13                         country             488                0.004087
# 10                        children               4                0.000034
# 19              reserved_room_type               0                0.000000
# 20              assigned_room_type               0                0.000000
# 21                 booking_changes               0                0.000000
# 22                    deposit_type               0                0.000000
# 0                            hotel               0                0.000000
# 17          previous_cancellations               0                0.000000
# 25            days_in_waiting_list               0                0.000000
# 26                   customer_type               0                0.000000
# 27                             adr               0                0.000000
# 28     required_car_parking_spaces               0                0.000000
# 29       total_of_special_requests               0                0.000000
# 30              reservation_status               0                0.000000
# 18  previous_bookings_not_canceled               0                0.000000
# 16               is_repeated_guest               0                0.000000
# 1                      is_canceled               0                0.000000
# 15            distribution_channel               0                0.000000
# 14                  market_segment               0                0.000000
# 12                            meal               0                0.000000
# 11                          babies               0                0.000000
# 9                           adults               0                0.000000
# 8             stays_in_week_nights               0                0.000000
# 7          stays_in_weekend_nights               0                0.000000
# 6        arrival_date_day_of_month               0                0.000000
# 5         arrival_date_week_number               0                0.000000
# 4               arrival_date_month               0                0.000000
# 3                arrival_date_year               0                0.000000
# 2                        lead_time               0                0.000000
# 31         reservation_status_date               0                0.000000

# %%
most_frequent_agentid = df['agent'].mode()[0]
most_frequent_companyid = df['company'].mode()[0]
most_frequent_country = df['country'].mode()[0]
most_frequent_children = df['children'].mode()[0]

df['agent'].fillna(most_frequent_agentid, inplace=True)
df['children'].fillna(most_frequent_children, inplace=True)
df['company'].fillna(most_frequent_companyid, inplace=True)
df['country'].fillna(most_frequent_country, inplace=True)

# %%
features_stat = df.isna().sum().rename('num_of_missing').reset_index()
features_stat.columns = ['feature', 'num_of_missing']
features_stat['percentage_of_missings'] = features_stat['num_of_missing'].apply(lambda x:x/len(df))
features_stat.sort_values(by='percentage_of_missings',ascending=False)
# Out:
#                            feature  num_of_missing  percentage_of_missings
# 0                            hotel               0                     0.0
# 1                      is_canceled               0                     0.0
# 30              reservation_status               0                     0.0
# 29       total_of_special_requests               0                     0.0
# 28     required_car_parking_spaces               0                     0.0
# 27                             adr               0                     0.0
# 26                   customer_type               0                     0.0
# 25            days_in_waiting_list               0                     0.0
# 24                         company               0                     0.0
# 23                           agent               0                     0.0
# 22                    deposit_type               0                     0.0
# 21                 booking_changes               0                     0.0
# 20              assigned_room_type               0                     0.0
# 19              reserved_room_type               0                     0.0
# 18  previous_bookings_not_canceled               0                     0.0
# 17          previous_cancellations               0                     0.0
# 16               is_repeated_guest               0                     0.0
# 15            distribution_channel               0                     0.0
# 14                  market_segment               0                     0.0
# 13                         country               0                     0.0
# 12                            meal               0                     0.0
# 11                          babies               0                     0.0
# 10                        children               0                     0.0
# 9                           adults               0                     0.0
# 8             stays_in_week_nights               0                     0.0
# 7          stays_in_weekend_nights               0                     0.0
# 6        arrival_date_day_of_month               0                     0.0
# 5         arrival_date_week_number               0                     0.0
# 4               arrival_date_month               0                     0.0
# 3                arrival_date_year               0                     0.0
# 2                        lead_time               0                     0.0
# 31         reservation_status_date               0                     0.0

# %%
cols = ["children", "agent", "company"]
df[cols] = df[cols].applymap(np.int64)

# %%
datetime_object = df['arrival_date_month'].str[0:3]
month_number = np.zeros(len(datetime_object))

# Creating a new column based on numerical representation of the months
for i in range(0, len(datetime_object)):
    datetime_object[i] = datetime.datetime.strptime(datetime_object[i], "%b")
    month_number[i] = datetime_object[i].month

# Float to integer conversion
month_number = pd.DataFrame(month_number).astype(int)

df['arrival_date'] = df['arrival_date_year'].map(str) + '-' + month_number[0].map(str) + '-' \
                       + df['arrival_date_day_of_month'].map(str)

# Dropping already used columns
df = df.drop(['arrival_date_year', 'arrival_date_month', 'arrival_date_day_of_month',
                  'arrival_date_week_number'], axis=1)
df.head()
# Out:
#           hotel  is_canceled  lead_time  stays_in_weekend_nights  \
# 0  Resort Hotel            0        342                        0
# 1  Resort Hotel            0        737                        0
# 2  Resort Hotel            0          7                        0
# 3  Resort Hotel            0         13                        0
# 4  Resort Hotel            0         14                        0
#
#    stays_in_week_nights  adults  children  babies meal country  ... agent  \
# 0                     0       2         0       0   BB     PRT  ...     9
# 1                     0       2         0       0   BB     PRT  ...     9
# 2                     1       1         0       0   BB     GBR  ...     9
# 3                     1       1         0       0   BB     GBR  ...   304
# 4                     2       2         0       0   BB     GBR  ...   240
#
#   company  days_in_waiting_list  customer_type   adr  \
# 0      40                     0      Transient   0.0
# 1      40                     0      Transient   0.0
# 2      40                     0      Transient  75.0
# 3      40                     0      Transient  75.0
# 4      40                     0      Transient  98.0
#
#   required_car_parking_spaces total_of_special_requests  reservation_status  \
# 0                           0                         0           Check-Out
# 1                           0                         0           Check-Out
# 2                           0                         0           Check-Out
# 3                           0                         0           Check-Out
# 4                           0                         1           Check-Out
#
#   reservation_status_date  arrival_date
# 0              2015-07-01      2015-7-1
# 1              2015-07-01      2015-7-1
# 2              2015-07-02      2015-7-1
# 3              2015-07-02      2015-7-1
# 4              2015-07-03      2015-7-1
#
# [5 rows x 29 columns]

# %%
df['arrival_date'] = pd.to_datetime(df['arrival_date'])
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])

print('Datatype of the arrival_date:', df['arrival_date'].dtype)
print('Datatype of the reservation_status_date:', df['reservation_status_date'].dtype)
# Out:
# Datatype of the arrival_date: datetime64[ns]
# Datatype of the reservation_status_date: datetime64[ns]

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(timeseries):
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)
    
df['Total Guests'] = df['adults'] + df['children']
adf_test(NumberOfGuests_Daily['Total Guests'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File C:\Anaconda3\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:440, in pandas._libs.tslibs.parsing.parse_datetime_string_with_reso()
#
# File C:\Anaconda3\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:649, in pandas._libs.tslibs.parsing.dateutil_parse()
#
# ValueError: Unknown datetime string format, unable to parse: Total Guests
#
# During handling of the above exception, another exception occurred:
#
# DateParseError                            Traceback (most recent call last)
# File C:\Anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py:704, in DatetimeIndex.get_loc(self, key, method, tolerance)
#     703 try:
# --> 704     parsed, reso = self._parse_with_reso(key)
#     705 except ValueError as err:
#
# File C:\Anaconda3\lib\site-packages\pandas\core\indexes\datetimelike.py:230, in DatetimeIndexOpsMixin._parse_with_reso(self, label)
#     229     freq = getattr(self, "freqstr", getattr(self, "inferred_freq", None))
# --> 230 parsed, reso_str = parsing.parse_time_string(label, freq)
#     231 reso = Resolution.from_attrname(reso_str)
#
# File C:\Anaconda3\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:367, in pandas._libs.tslibs.parsing.parse_time_string()
#
# File C:\Anaconda3\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:445, in pandas._libs.tslibs.parsing.parse_datetime_string_with_reso()
#
# DateParseError: Unknown datetime string format, unable to parse: Total Guests
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[140], line 12
#       9     print (dfoutput)
#      11 df['Total Guests'] = df['adults'] + df['children']
# ---> 12 adf_test(NumberOfGuests_Daily['Total Guests'])
#
# File C:\Anaconda3\lib\site-packages\pandas\core\series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File C:\Anaconda3\lib\site-packages\pandas\core\series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File C:\Anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py:706, in DatetimeIndex.get_loc(self, key, method, tolerance)
#     704     parsed, reso = self._parse_with_reso(key)
#     705 except ValueError as err:
# --> 706     raise KeyError(key) from err
#     707 self._deprecate_mismatched_indexing(parsed, one_way=True)
#     709 if self._can_partial_date_slice(reso):
#
# KeyError: 'Total Guests'

# %%
dataNoCancel = df[df['is_canceled'] == 0]
dataNoCancel = dataNoCancel.reset_index(drop=True)

NumberOfGuests_Daily = dataNoCancel['Total Guests'].groupby(dataNoCancel['arrival_date']).sum()
NumberOfGuests_Daily = NumberOfGuests_Daily.resample('d').sum().to_frame()

from statsmodels.tsa.stattools import kpss
def kpss_test(timeseries):
    print ('Results of KPSS Test:')
    kpsstest = kpss(timeseries, regression='c', nlags="auto")
    kpss_output = pd.Series(kpsstest[0:3], index=['Test Statistic','p-value','Lags Used'])
    for key,value in kpsstest[3].items():
        kpss_output['Critical Value (%s)'%key] = value
    print (kpss_output)
    
kpss_test(NumberOfGuests_Daily['Total Guests'])
# Out:
# Results of KPSS Test:
# Test Statistic            1.53475
# p-value                   0.01000
# Lags Used                16.00000
# Critical Value (10%)      0.34700
# Critical Value (5%)       0.46300
# Critical Value (2.5%)     0.57400
# Critical Value (1%)       0.73900
# dtype: float64

# %%
def obtain_adf_kpss_results(timeseries, max_d):
    results=[]
    for idx in range(max_d):
        adf_result = adfuller(timeseries, autolag='AIC')
        kpss_result = kpss(timeseries, regression='c', nlags="auto")
        timeseries = timeseries.diff().dropna()
        if adf_result[1] <=0.05:
            adf_stationary = True
        else:
            adf_stationary = False
        if kpss_result[1] <=0.05:
            kpss_stationary = False
        else:
            kpss_stationary = True
            
        stationary = adf_stationary & kpss_stationary
        results.append((idx,adf_result[1], kpss_result[1],adf_stationary,kpss_stationary, stationary))
    
    # Construct DataFrame 
    results_df = pd.DataFrame(results, columns=['d','adf_stats','p-value', 'is_adf_stationary','is_kpss_stationary','is_stationary' ])
    
    return results_df

obtain_adf_kpss_results(NumberOfGuests_Daily, 3)
# Out:
#    d     adf_stats  p-value  is_adf_stationary  is_kpss_stationary  \
# 0  0  9.226256e-02     0.01              False               False
# 1  1  3.915824e-18     0.10               True                True
# 2  2  1.773664e-24     0.10               True                True
#
#    is_stationary
# 0          False
# 1           True
# 2           True

# %%
NumberOfGuests_Daily.plot(grid=True,figsize=(8,3), title = "Original timeseries" )
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Create figure
fig, (ax1, ax2) = plt.subplots(2,1, figsize=(12,8))
 
# Plot the ACF of NumberOfGuests_Daily
plot_acf(NumberOfGuests_Daily.diff().dropna(),lags=14, zero=False, ax=ax1)

# Plot the PACF of NumberOfGuests_Daily
plot_pacf(NumberOfGuests_Daily.diff().dropna(),lags=14, zero=False, ax=ax2)

plt.show()

# %%
NumberOfGuests_Daily.index = pd.DatetimeIndex(NumberOfGuests_Daily.index.values,
                               freq=NumberOfGuests_Daily.index.inferred_freq)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# just an example
model = SARIMAX(NumberOfGuests_Daily, order=(1,1,1), freq='D')
results = model.fit()
# statistics of the model
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:           Total Guests   No. Observations:                  793
# Model:               SARIMAX(1, 1, 1)   Log Likelihood               -4325.667
# Date:                Wed, 25 Sep 2024   AIC                           8657.334
# Time:                        16:19:27   BIC                           8671.357
# Sample:                    07-01-2015   HQIC                          8662.723
#                          - 08-31-2017
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0205      0.036      0.575      0.565      -0.049       0.091
# ma.L1         -0.8957      0.017    -52.275      0.000      -0.929      -0.862
# sigma2      3240.7410     98.905     32.766      0.000    3046.890    3434.592
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               649.90
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.62   Skew:                             1.09
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.86
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Create empty list to store search results
order_aic_bic=[]

# Loop over p values from 0-6
for p in range(7):
  # Loop over q values from 0-6
    for q in range(7):
      	# create and fit ARMA(p,q) model
        model = SARIMAX(NumberOfGuests_Daily, order=(p,1,q), freq="D") #because adf test showed that d=1
        results = model.fit()
        
        # Append order and results tuple
        order_aic_bic.append((p,q,results.aic, results.bic))

# %%
# Construct DataFrame from order_aic_bic
order_df = pd.DataFrame(order_aic_bic, 
                        columns=['p','q','AIC','BIC'])

# Print order_df in order of increasing AIC
order_df.sort_values('AIC')
# Out:
#     p  q          AIC          BIC
# 48  6  6  8609.780263  8670.549561
# 41  5  6  8611.439867  8667.534603
# 47  6  5  8618.505524  8674.600260
# 27  3  6  8628.455824  8675.201438
# 42  6  0  8633.175905  8665.897835
# 45  6  3  8634.850516  8681.596130
# 43  6  1  8635.092216  8672.488707
# 46  6  4  8635.960355  8687.380530
# 17  2  3  8636.296060  8664.343428
# 44  6  2  8636.360834  8678.431887
# 19  2  5  8636.685105  8674.081596
# 31  4  3  8637.030025  8674.426516
# 24  3  3  8637.958852  8670.680782
# 38  5  3  8639.482192  8681.553245
# 32  4  4  8647.977826  8690.048878
# 25  3  4  8649.012561  8686.409052
# 26  3  5  8649.137037  8691.208090
# 39  5  4  8649.603227  8696.348841
# 9   1  2  8649.804966  8668.503212
# 33  4  5  8651.026302  8697.771915
# 40  5  5  8651.892285  8703.312460
# 34  4  6  8651.954103  8703.374278
# 16  2  2  8655.106365  8678.479172
# 10  1  3  8655.131730  8678.504537
# 1   0  1  8655.589618  8664.938741
# 23  3  2  8656.374631  8684.421999
# 11  1  4  8656.442098  8684.489467
# 2   0  2  8657.325571  8671.349256
# 8   1  1  8657.333584  8671.357269
# 18  2  4  8657.718707  8690.440637
# 30  4  2  8658.362834  8691.084763
# 12  1  5  8658.426397  8691.148326
# 20  2  6  8658.457044  8700.528097
# 37  5  2  8658.929498  8696.325990
# 3   0  3  8659.170752  8677.868997
# 15  2  1  8659.205112  8677.903358
# 4   0  4  8659.847248  8683.220055
# 22  3  1  8659.895010  8683.267817
# 13  1  6  8659.907500  8697.303992
# 5   0  5  8661.193108  8689.240476
# 29  4  1  8661.870414  8689.917782
# 6   0  6  8662.342789  8695.064718
# 36  5  1  8663.138397  8695.860326
# 35  5  0  8717.903048  8745.950417
# 28  4  0  8736.947958  8760.320765
# 21  3  0  8755.139517  8773.837763
# 14  2  0  8791.802429  8805.826113
# 7   1  0  8895.792187  8905.141310
# 0   0  0  9101.889451  9106.564013

# %%
df_train = NumberOfGuests_Daily[:701]
df_test = NumberOfGuests_Daily[701:]


arima_model = SARIMAX(df_train, order=(6,1,6))
# fit model
arima_results = arima_model.fit()
yhat = arima_results.forecast(len(df_test))
# Calculate the mean absolute error from residuals
#mae = np.mean(np.abs(arima_results.resid))
MAE_1 = mean_absolute_error(df_test, yhat)

print('MAE: %.3f' % MAE_1)

MAPE_1 = mean_absolute_percentage_error(df_test, yhat)
print('MAPE: %.3f' % MAPE_1)
# Out:
# MAE: 30.703
# MAPE: 0.141

# %%
ax = df_test['Total Guests'].plot(legend=True,figsize=(12,6),title='Total Guests Forecasted')
yhat.plot(legend=True)
ax.autoscale(axis='x',tight=True)
ax.set(ylabel='Total Guests');

# %%
arima_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:           Total Guests   No. Observations:                  701
# Model:               SARIMAX(6, 1, 6)   Log Likelihood               -3815.996
# Date:                Wed, 25 Sep 2024   AIC                           7657.992
# Time:                        16:24:19   BIC                           7717.156
# Sample:                    07-01-2015   HQIC                          7680.862
#                          - 05-31-2017
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.9424      0.236     -3.986      0.000      -1.406      -0.479
# ar.L2         -0.1809      0.111     -1.624      0.104      -0.399       0.037
# ar.L3         -0.5023      0.065     -7.752      0.000      -0.629      -0.375
# ar.L4         -1.1662      0.129     -9.038      0.000      -1.419      -0.913
# ar.L5         -0.5288      0.221     -2.392      0.017      -0.962      -0.095
# ar.L6         -0.1340      0.054     -2.467      0.014      -0.241      -0.028
# ma.L1          0.0621      0.242      0.257      0.797      -0.412       0.536
# ma.L2         -0.7026      0.119     -5.925      0.000      -0.935      -0.470
# ma.L3          0.3614      0.145      2.491      0.013       0.077       0.646
# ma.L4          0.7756      0.165      4.706      0.000       0.453       1.099
# ma.L5         -0.5013      0.120     -4.191      0.000      -0.736      -0.267
# ma.L6         -0.3881      0.201     -1.928      0.054      -0.783       0.006
# sigma2      3299.3762    114.355     28.852      0.000    3075.244    3523.508
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.22   Jarque-Bera (JB):               737.45
# Prob(Q):                              0.64   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.73   Skew:                             1.15
# Prob(H) (two-sided):                  0.02   Kurtosis:                         7.47
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Take the first and seasonal differences (S=7) and drop NaNs
NumberOfGuests_Daily_diff = NumberOfGuests_Daily.diff().diff(7).dropna()

# %%
# Create the figure 
fig, (ax1, ax2) = plt.subplots(2,1,figsize=(8,6))

# Plot the ACF on ax1
plot_acf(NumberOfGuests_Daily_diff, lags=14, zero=False, ax=ax1)

# Plot the PACF on ax2
plot_pacf(NumberOfGuests_Daily_diff, lags=14, zero=False, ax=ax2)

plt.show()

# %%
lags = [7, 14, 21, 28, 35]

# Create the figure 
fig, (ax1, ax2) = plt.subplots(2,1,figsize=(8,6))

# Plot the ACF on ax1
plot_acf(NumberOfGuests_Daily_diff, lags=lags, zero=False, ax=ax1)

# Plot the PACF on ax2
plot_pacf(NumberOfGuests_Daily_diff, lags=lags, zero=False, ax=ax2)

plt.show()

# %%
sarima_01_model = SARIMAX(df_train, order=(0,1,6), seasonal_order=(0,1,1,7))

# fit model
sarima_01_results = sarima_01_model.fit()
yhat = sarima_01_results.forecast(len(df_test))
# Calculate the mean absolute error from residuals
#mae = np.mean(np.abs(arima_results.resid))
MAE_2 = mean_absolute_error(df_test, yhat)

print('MAE: %.3f' % MAE_2)

MAPE_2 = mean_absolute_percentage_error(df_test, yhat)
print('MAPE: %.3f' % MAPE_2)
# Out:
# MAE: 29.703
# MAPE: 0.141

# %%
ax = df_test['Total Guests'].plot(legend=True,figsize=(12,6),title='Total Guests Forecasted')
yhat.plot(legend=True)
ax.autoscale(axis='x',tight=True)
ax.set(ylabel='Total Guests');

# %%
sarima_01_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                        Total Guests   No. Observations:                  701
# Model:             SARIMAX(0, 1, 6)x(0, 1, [1], 7)   Log Likelihood               -3778.280
# Date:                             Wed, 25 Sep 2024   AIC                           7572.560
# Time:                                     16:25:30   BIC                           7608.888
# Sample:                                 07-01-2015   HQIC                          7586.609
#                                       - 05-31-2017
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.8712      0.033    -26.144      0.000      -0.936      -0.806
# ma.L2         -0.0208      0.041     -0.509      0.611      -0.101       0.059
# ma.L3          0.0833      0.047      1.789      0.074      -0.008       0.174
# ma.L4         -0.0425      0.054     -0.783      0.434      -0.149       0.064
# ma.L5         -0.0320      0.056     -0.571      0.568      -0.142       0.078
# ma.L6         -0.0026      0.044     -0.060      0.952      -0.088       0.083
# ma.S.L7       -0.9985      0.116     -8.593      0.000      -1.226      -0.771
# sigma2      3033.4813    349.572      8.678      0.000    2348.332    3718.630
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               708.91
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.75   Skew:                             1.07
# Prob(H) (two-sided):                  0.03   Kurtosis:                         7.46
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
import pmdarima as pm

# Create auto_arima model
model1 = pm.auto_arima(NumberOfGuests_Daily, #time series
                      seasonal=True, # is the time series seasonal
                      m=7, # the seasonal period - one week?
                      d=1, # non-seasonal difference order
                      D=1, # seasonal difference order
                 	  max_p=6, # max value of p to test 
                      max_q=6, # max value of p to test
                      max_P=6, # max value of P to test 
                      max_Q=6, # max value of Q to test 
                      information_criterion='aic', # used to select best mode
                      trace=True, # prints the information_criterion for each model it fits
                      error_action='ignore', # ignore orders that don't work
                      stepwise=True, # apply an intelligent order search
                      suppress_warnings=True) 

# Print model summary
print(model1.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[7]             : AIC=inf, Time=4.83 sec
#  ARIMA(0,1,0)(0,1,0)[7]             : AIC=9340.252, Time=0.10 sec
#  ARIMA(1,1,0)(1,1,0)[7]             : AIC=8917.551, Time=0.64 sec
#  ARIMA(0,1,1)(0,1,1)[7]             : AIC=inf, Time=1.46 sec
#  ARIMA(1,1,0)(0,1,0)[7]             : AIC=9128.723, Time=0.13 sec
#  ARIMA(1,1,0)(2,1,0)[7]             : AIC=8852.348, Time=0.92 sec
#  ARIMA(1,1,0)(3,1,0)[7]             : AIC=8832.733, Time=2.25 sec
#  ARIMA(1,1,0)(4,1,0)[7]             : AIC=8817.022, Time=3.93 sec
#  ARIMA(1,1,0)(5,1,0)[7]             : AIC=8796.175, Time=4.51 sec
#  ARIMA(1,1,0)(6,1,0)[7]             : AIC=8791.410, Time=6.44 sec
#  ARIMA(1,1,0)(6,1,1)[7]             : AIC=inf, Time=20.26 sec
#  ARIMA(1,1,0)(5,1,1)[7]             : AIC=inf, Time=10.85 sec
#  ARIMA(0,1,0)(6,1,0)[7]             : AIC=9013.348, Time=4.51 sec
#  ARIMA(2,1,0)(6,1,0)[7]             : AIC=8686.319, Time=6.02 sec
#  ARIMA(2,1,0)(5,1,0)[7]             : AIC=8692.075, Time=6.74 sec
#  ARIMA(2,1,0)(6,1,1)[7]             : AIC=inf, Time=19.72 sec
#  ARIMA(2,1,0)(5,1,1)[7]             : AIC=inf, Time=14.98 sec
#  ARIMA(3,1,0)(6,1,0)[7]             : AIC=8652.567, Time=7.68 sec
#  ARIMA(3,1,0)(5,1,0)[7]             : AIC=8655.446, Time=5.56 sec
#  ARIMA(3,1,0)(6,1,1)[7]             : AIC=inf, Time=20.52 sec
#  ARIMA(3,1,0)(5,1,1)[7]             : AIC=inf, Time=15.92 sec
#  ARIMA(4,1,0)(6,1,0)[7]             : AIC=8634.627, Time=9.10 sec
#  ARIMA(4,1,0)(5,1,0)[7]             : AIC=8637.228, Time=6.21 sec
#  ARIMA(4,1,0)(6,1,1)[7]             : AIC=inf, Time=23.92 sec
#  ARIMA(4,1,0)(5,1,1)[7]             : AIC=inf, Time=19.02 sec
#  ARIMA(5,1,0)(6,1,0)[7]             : AIC=8620.664, Time=9.45 sec
#  ARIMA(5,1,0)(5,1,0)[7]             : AIC=8623.109, Time=7.49 sec
#  ARIMA(5,1,0)(6,1,1)[7]             : AIC=inf, Time=31.67 sec
#  ARIMA(5,1,0)(5,1,1)[7]             : AIC=inf, Time=22.69 sec
#  ARIMA(6,1,0)(6,1,0)[7]             : AIC=8600.123, Time=11.83 sec
#  ARIMA(6,1,0)(5,1,0)[7]             : AIC=8604.899, Time=10.69 sec
#  ARIMA(6,1,0)(6,1,1)[7]             : AIC=inf, Time=35.42 sec
#  ARIMA(6,1,0)(5,1,1)[7]             : AIC=inf, Time=31.66 sec
#  ARIMA(6,1,1)(6,1,0)[7]             : AIC=inf, Time=40.22 sec
#  ARIMA(5,1,1)(6,1,0)[7]             : AIC=inf, Time=19.17 sec
#  ARIMA(6,1,0)(6,1,0)[7] intercept   : AIC=8602.089, Time=26.32 sec
#
# Best model:  ARIMA(6,1,0)(6,1,0)[7]
# Total fit time: 462.939 seconds
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                                 y   No. Observations:                  793
# Model:             SARIMAX(6, 1, 0)x(6, 1, 0, 7)   Log Likelihood               -4287.061
# Date:                           Wed, 25 Sep 2024   AIC                           8600.123
# Time:                                   16:33:55   BIC                           8660.777
# Sample:                               07-01-2015   HQIC                          8623.444
#                                     - 08-31-2017
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.8759      0.033    -26.748      0.000      -0.940      -0.812
# ar.L2         -0.7359      0.046    -16.002      0.000      -0.826      -0.646
# ar.L3         -0.5994      0.054    -11.147      0.000      -0.705      -0.494
# ar.L4         -0.5087      0.058     -8.737      0.000      -0.623      -0.395
# ar.L5         -0.4322      0.062     -6.998      0.000      -0.553      -0.311
# ar.L6         -0.3478      0.063     -5.560      0.000      -0.470      -0.225
# ar.S.L7       -1.0370      0.064    -16.173      0.000      -1.163      -0.911
# ar.S.L14      -0.8430      0.090     -9.375      0.000      -1.019      -0.667
# ar.S.L21      -0.6199      0.091     -6.805      0.000      -0.798      -0.441
# ar.S.L28      -0.4602      0.077     -5.982      0.000      -0.611      -0.309
# ar.S.L35      -0.3218      0.062     -5.206      0.000      -0.443      -0.201
# ar.S.L42      -0.0953      0.042     -2.276      0.023      -0.177      -0.013
# sigma2      3212.9646    104.864     30.639      0.000    3007.436    3418.494
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):               886.90
# Prob(Q):                              0.92   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.59   Skew:                             0.95
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.85
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
sarima_02_model = SARIMAX(df_train, order=(6,1,0), seasonal_order=(6,1,0,7))
sarima_02_results = sarima_02_model.fit()

yhat = sarima_02_results.forecast(len(df_test))
# Calculate the mean absolute error from test data
MAE_3 = mean_absolute_error(df_test, yhat)

# Print mean absolute error
print('MAE: %.3f' % MAE_3)

MAPE_3 = mean_absolute_percentage_error(df_test, yhat)
print('MAPE: %.3f' % MAPE_3)
# Out:
# MAE: 33.508
# MAPE: 0.155

# %%
ax = df_test['Total Guests'].plot(legend=True,figsize=(12,6),title='Total Guests Forecasted')
yhat.plot(legend=True)
ax.autoscale(axis='x',tight=True)
ax.set(ylabel='Total Guests');

# %%
df_arima_results = pd.DataFrame({'metrics':['MAE','MAPE'],
              'ARIMA(6,1,6)':[round(MAE_1,3), 
                 round(MAPE_1,4)], 
              'SARIMA(0,1,6)(0,1,1)7':[round(MAE_2,3), 
                 round(MAPE_2,4)],
              'SARIMA(6,1,0)(6,1,0)7':[round(MAE_3,3), 
                 round(MAPE_3,4)]
             })

df_arima_results
# Out:
#   metrics  ARIMA(6,1,6)  SARIMA(0,1,6)(0,1,1)7  SARIMA(6,1,0)(6,1,0)7
# 0     MAE       30.7030                29.7030                33.5080
# 1    MAPE        0.1413                 0.1411                 0.1551
